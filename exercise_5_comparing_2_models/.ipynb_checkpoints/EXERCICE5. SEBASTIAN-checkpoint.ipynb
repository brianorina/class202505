# %% [markdown]
# EXERCICE: Choose type of ML, ML regression, ML classification, Unsupervised clustering
# I need to choose 2 ML algorithms + Make the models, compare the metrics MAE, MSE, R2, MAPE

# %% [markdown]
# 0. iNSTAL LIBRARIES

# %%
pip install yfinance pandas scikit-learn xgboost matplotlib
# Out:
# Requirement already satisfied: yfinance in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (0.2.63)
# Requirement already satisfied: pandas in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (1.6.1)
# Requirement already satisfied: xgboost in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (0.11.4)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: pycparser in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\socio\anaconda3\envs\mi_entorno_ml\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. DOWNLOAD DATASET

# %%
import yfinance as yf
import pandas as pd

# Descargar datos de BTC hasta el 18 de junio de 2025
btc = yf.download('BTC-USD', start='2020-01-01', end='2025-06-19')  # el end es exclusivo, por eso usamos 19
btc = btc[['Open', 'High', 'Low', 'Close', 'Volume']]
btc.dropna(inplace=True)

# Crear la variable objetivo: el precio de cierre del día actual
btc['Target'] = btc['Close']

# Eliminar la última fila para evitar datos futuros
btc = btc.iloc[:-1]
# Out:
# C:\Users\Socio\AppData\Local\Temp\ipykernel_12676\291300055.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download('BTC-USD', start='2020-01-01', end='2025-06-19')  # el end es exclusivo, por eso usamos 19
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 2. SEPARATE THE DATA AND TRAIN THE REGRESION MODELS

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Definir variables predictoras y objetivo
X = btc[['Open', 'High', 'Low', 'Volume']]
y = btc['Target']

# Dividir en conjuntos de entrenamiento y prueba (80% entrenamiento, 20% prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Entrenar los modelos
modelo_lr = LinearRegression()
modelo_rf = RandomForestRegressor()

modelo_lr.fit(X_train, y_train)
modelo_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# 3. MAKE PREDICTIONS AND CALCULATE METRICS

# %%
# Hacer predicciones
pred_lr = modelo_lr.predict(X_test)
pred_rf = modelo_rf.predict(X_test)

# Función de evaluación
def evaluar(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return mae, mse, r2, mape

# Evaluar ambos modelos
res_lr = evaluar(y_test, pred_lr)
res_rf = evaluar(y_test, pred_rf)

# Mostrar resultados
print("Regresión Lineal -> MAE: %.2f | MSE: %.2f | R²: %.4f | MAPE: %.2f%%" % res_lr)
print("Random Forest     -> MAE: %.2f | MSE: %.2f | R²: %.4f | MAPE: %.2f%%" % res_rf)
# Out:
# Regresión Lineal -> MAE: 617.56 | MSE: 772007.64 | R²: 0.9974 | MAPE: 0.76%
# Random Forest     -> MAE: 13033.40 | MSE: 330727941.63 | R²: -0.1253 | MAPE: 13.49%

# %%
# Evaluar los modelos
res_lr = evaluar(y_test, pred_lr)
res_rf = evaluar(y_test, pred_rf)

# Desempaquetar las métricas
mae_lr, mse_lr, r2_lr, mape_lr = res_lr
mae_rf, mse_rf, r2_rf, mape_rf = res_rf

# Imprimir métricas
print("\nMÉTRICAS DE LOS MODELOS:")
print(f"Regresión Lineal -> MAE: {mae_lr:.2f} | MSE: {mse_lr:.2f} | R²: {r2_lr:.4f} | MAPE: {mape_lr:.2f}%")
print(f"Random Forest     -> MAE: {mae_rf:.2f} | MSE: {mse_rf:.2f} | R²: {r2_rf:.4f} | MAPE: {mape_rf:.2f}%")

# Generar conclusión
print("\nCONCLUSIÓN AUTOMÁTICA:")
if r2_lr > r2_rf and mae_lr < mae_rf and mape_lr < mape_rf:
    print("El modelo de Regresión Lineal tuvo un mejor rendimiento general en la predicción del precio de Bitcoin,")
    print("mostrando mayor precisión y menor error que el modelo Random Forest.")
elif r2_rf > r2_lr and mae_rf < mae_lr and mape_rf < mape_lr:
    print("El modelo Random Forest mostró un mejor rendimiento general frente a la Regresión Lineal,")
    print("siendo más preciso al predecir el precio de Bitcoin.")
else:
    print("Ambos modelos ofrecen resultados distintos y podrían combinarse o ajustarse con más variables")
    print("para mejorar la precisión de las predicciones.")
# Out:
# MÉTRICAS DE LOS MODELOS:
# Regresión Lineal -> MAE: 617.56 | MSE: 772007.64 | R²: 0.9974 | MAPE: 0.76%
# Random Forest     -> MAE: 13033.40 | MSE: 330727941.63 | R²: -0.1253 | MAPE: 13.49%
#
# CONCLUSIÓN AUTOMÁTICA:
# El modelo de Regresión Lineal tuvo un mejor rendimiento general en la predicción del precio de Bitcoin,
# mostrando mayor precisión y menor error que el modelo Random Forest.

# %%
Regresión Lineal predijo el precio de Bitcoin con muchísima precisión:

Error muy bajo (MAE: 617)

Casi perfecto en explicarlo todo (R²: 0.997)

Muy poco porcentaje de fallo (MAPE: 0.76%)

Random Forest falló bastante:

Error enorme (MAE: 13.000+)

R² negativo: significa que no entendió la relación entre los datos

Error porcentual alto (MAPE: 13%+)

# %% [markdown]
# BITCOIN HISTORIC PRICE

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(btc.index, btc['Close'], label='Precio de Cierre', color='orange')
plt.title('Precio Histórico de Bitcoin')
plt.xlabel('Fecha')
plt.ylabel('Precio (USD)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

# Colores: real en negro, LR en violeta fluorescente, RF en azul eléctrico
plt.plot(y_test.index, y_test.values, label='Real', color='black', linewidth=2)
plt.plot(y_test.index, pred_lr, label='Predicción LR', linestyle='--', color='#D000FF', linewidth=2)  # violeta fluorescente
plt.plot(y_test.index, pred_rf, label='Predicción RF', linestyle='--', color='#00BFFF', linewidth=2)  # azul eléctrico

plt.title('Predicciones vs Real - Regresión Lineal y Random Forest')
plt.xlabel('Fecha')
plt.ylabel('Precio de BTC (USD)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Negra: valor real del precio de cierre de Bitcoin → nuestra base de comparación.
#
# Violeta punteada: predicción del modelo de Regresión Lineal.
#
# Azul celeste punteada

# %% [markdown]
# CROSS VALIDATION

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Crear el objeto TimeSeriesSplit con 5 particiones
tscv = TimeSeriesSplit(n_splits=5)

# Función para evaluar un modelo usando validación cruzada temporal
def cross_validate_model(model, X, y):
    mae_scores, mse_scores, r2_scores, mape_scores = [], [], [], []

    for train_idx, test_idx in tscv.split(X):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_train)
        preds = model.predict(X_test)

        mae_scores.append(mean_absolute_error(y_test, preds))
        mse_scores.append(mean_squared_error(y_test, preds))
        r2_scores.append(r2_score(y_test, preds))
        mape_scores.append(np.mean(np.abs((y_test - preds) / y_test)) * 100)

    # Mostrar promedios finales
    print("\nVALIDACIÓN CRUZADA TEMPORAL:")
    print("Promedio MAE: %.2f" % np.mean(mae_scores))
    print("Promedio MSE: %.2f" % np.mean(mse_scores))
    print("Promedio R²: %.4f" % np.mean(r2_scores))
    print("Promedio MAPE: %.2f%%" % np.mean(mape_scores))

# %%
cross_validate_model(modelo_lr, X, y)
# Out:
# VALIDACIÓN CRUZADA TEMPORAL:
# Promedio MAE: 437.79
# Promedio MSE: 437750.57
# Promedio R²: 0.9973
# Promedio MAPE: 0.94%

# %%
cross_validate_model(modelo_rf, X, y)
# Out:
# VALIDACIÓN CRUZADA TEMPORAL:
# Promedio MAE: 8393.78
# Promedio MSE: 226520193.35
# Promedio R²: -0.3932
# Promedio MAPE: 14.67%

# %% [markdown]
# Con la Regresión Lineal, podemos predecir aproximadamente cuánto costará el Bitcoin con base en datos anteriores como apertura, volumen, etc. Si el modelo predice que el precio va a subir, podrías anticiparte y comprar. Si predice que bajará, podrías vender o esperar.
