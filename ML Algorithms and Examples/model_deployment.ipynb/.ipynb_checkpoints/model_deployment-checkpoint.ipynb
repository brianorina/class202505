# %%
import sklearn

import joblib

# Save the best_elasticnet_model to a file
model = joblib.load('best_elasticnet_model.pkl')

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(transformers=[('num',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer(strategy='median')),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['distance_to_center',
#                                                                     'days_in_advance',
#                                                                     'length_of_stay',
#                                                                     'nr_previous_bookings']),
#                                                                   ('cat',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer(strategy='most_frequent'))...
#                                                                                                   sparse_output=False))]),
#                                                                    ['month',
#                                                                     'day_of_week',
#                                                                     'hotel_category',
#                                                                     'room_capacity']),
#                                                                   ('bin',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer(strategy='most_frequent'))]),
#                                                                    ['is_weekend',
#                                                                     'is_high_season',
#                                                                     'has_pool',
#                                                                     'has_spa',
#                                                                     'has_gym'])])),
#                                  ('poly',
#                                   PolynomialFeatures(include_bias=False,
#                                                      interaction_only=True))])),
#                 ('elasticnet',
#                  ElasticNet(alpha=0.01, l1_ratio=0.9, max_iter=10000))])

# %%
import pandas as pd

example_hotels = pd.DataFrame({
    'month': [7, 7, 1, 12],  # July, July, January, December
    'day_of_week': [5, 1, 3, 6],  # Saturday, Tuesday, Thursday, Sunday
    'is_weekend': [1, 0, 0, 1],
    'is_high_season': [1, 1, 0, 1],
    'hotel_category': [4, 3, 5, 5],  
    'distance_to_center': [1.5, 4.0, 0.5, 2.0],
    'has_pool': [1, 0, 1, 1],
    'has_spa': [1, 0, 1, 1],
    'has_gym': [1, 1, 1, 1],
    'room_capacity': [2, 2, 1, 3],
    'days_in_advance': [30, 10, 90, 180],
    'length_of_stay': [7, 3, 2, 10],
    'nr_previous_bookings': [2, 0, 5, 1]
})


# Make predictions
predicted_prices = model.predict(example_hotels)

# %%
predicted_prices
# Out:
# array([277.9040255 , 180.17952313, 223.9868191 , 302.34396218])
